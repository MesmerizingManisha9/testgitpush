# %%
#installing the library
import pandas as pd
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
#loading the dataset with PANDAS
Aug= pd.read_csv('https://raw.githubusercontent.com/MesmerizingManisha9/testgitpush/master/aug_test.csv')

# %% [markdown]
# ## DATASET aug_test.csv
# # PANDAS

# %%
Aug
# Out:
#      SL No               Agent       Date Login Time Logout Time   Duration
# 0        1  Shivananda Sonwane  30-Jul-22   15:35:29    17:39:39   02:04:10
# 1        2      Khushboo Priya  30-Jul-22   15:06:59    15:07:16   00:00:17
# 2        3       Nandani Gupta  30-Jul-22   15:04:24    17:31:07   02:26:42
# 3        4     Hrisikesh Neogi  30-Jul-22   14:34:29    15:19:35   00:45:06
# 4        5              Mukesh  30-Jul-22   14:03:15    15:11:52   01:08:36
# ..     ...                 ...        ...        ...         ...        ...
# 995    996        Manjunatha A  20-Jul-22   09:03:51    15:02:28   05:58:37
# 996    997             Bharath  20-Jul-22   09:00:49    15:01:32   06:00:43
# 997    998      Khushboo Priya  20-Jul-22   08:59:20    14:26:55   05:27:34
# 998    999        Nishtha Jain  20-Jul-22   08:43:55    14:00:33   05:16:38
# 999   1000               Tarun  01-Jul-22   01:52:47    12:01:07  514:08:20
#
# [1000 rows x 6 columns]

# %%
Aug.head()
# Out:
#    enrollee_id      city  city_development_index  gender  \
# 0        32403   city_41                   0.827    Male
# 1         9858  city_103                   0.920  Female
# 2        31806   city_21                   0.624    Male
# 3        27385   city_13                   0.827    Male
# 4        27724  city_103                   0.920    Male
#
#        relevent_experience enrolled_university education_level  \
# 0  Has relevent experience    Full time course        Graduate
# 1  Has relevent experience       no_enrollment        Graduate
# 2   No relevent experience       no_enrollment     High School
# 3  Has relevent experience       no_enrollment         Masters
# 4  Has relevent experience       no_enrollment        Graduate
#
#   major_discipline experience company_size company_type last_new_job  \
# 0             STEM          9          <10          NaN            1
# 1             STEM          5          NaN      Pvt Ltd            1
# ...

# %%
#exploratory data analysis we'll start by checking out missing data
Aug.isnull()
# Out:
#       enrollee_id   city  city_development_index  gender  relevent_experience  \
# 0           False  False                   False   False                False
# 1           False  False                   False   False                False
# 2           False  False                   False   False                False
# 3           False  False                   False   False                False
# 4           False  False                   False   False                False
# ...           ...    ...                     ...     ...                  ...
# 2124        False  False                   False   False                False
# 2125        False  False                   False   False                False
# 2126        False  False                   False   False                False
# 2127        False  False                   False   False                False
# 2128        False  False                   False   False                False
#
# ...

# %% [markdown]
# # SEABORN
#
# ## HEATMAP
#
# ## DATASET aug_test.csv

# %%
#We can use seaborn to create a simple heatmap to see where we are missing data !


sns.heatmap(Aug.isnull(),yticklabels=True , cbar= True, cmap='viridis')
# Out:
# <AxesSubplot:>

# %% [markdown]
# ## COUNTPLOT

# %%
sns.countplot( x='gender', hue='education_level', data=Aug, palette="Set3")
# Out:
# <AxesSubplot:xlabel='gender', ylabel='count'>

# %% [markdown]
# # DATASET aug_train.csv &
# # hr_cleaned.csv

# %%
#loading the new TRAIN dataset with PANDAS
train= pd.read_csv('https://raw.githubusercontent.com/MesmerizingManisha9/testgitpush/master/aug_train.csv')
hr_cleaned= pd.read_csv('https://raw.githubusercontent.com/MesmerizingManisha9/testgitpush/master/hr_cleaned.csv')

# %%
train
# Out:
#            city  city_development_index gender      relevent_experience  \
# 0      city_103                   0.920   Male  Has relevent experience
# 1       city_40                   0.776   Male   No relevent experience
# 2       city_21                   0.624    NaN   No relevent experience
# 3      city_115                   0.789    NaN   No relevent experience
# 4      city_162                   0.767   Male  Has relevent experience
# ...         ...                     ...    ...                      ...
# 19153  city_173                   0.878   Male   No relevent experience
# 19154  city_103                   0.920   Male  Has relevent experience
# 19155  city_103                   0.920   Male  Has relevent experience
# 19156   city_65                   0.802   Male  Has relevent experience
# 19157   city_67                   0.855    NaN   No relevent experience
#
#       enrolled_university education_level major_discipline  experience  \
# ...

# %%
hr_cleaned
# Out:
#            city  city_development_index gender      relevent_experience  \
# 0      city_103                   0.920   Male  Has relevent experience
# 1       city_40                   0.776   Male   No relevent experience
# 2       city_21                   0.624    NaN   No relevent experience
# 3      city_115                   0.789    NaN   No relevent experience
# 4      city_162                   0.767   Male  Has relevent experience
# ...         ...                     ...    ...                      ...
# 19153  city_173                   0.878   Male   No relevent experience
# 19154  city_103                   0.920   Male  Has relevent experience
# 19155  city_103                   0.920   Male  Has relevent experience
# 19156   city_65                   0.802   Male  Has relevent experience
# 19157   city_67                   0.855    NaN   No relevent experience
#
#       enrolled_university education_level major_discipline  experience  \
# ...

# %%
sns.countplot( x='gender', hue='education_level', data=Aug, palette="Set3")
# Out:
# <AxesSubplot:xlabel='gender', ylabel='count'>

# %%
sns.set_style('whitegrid')
sns.countplot('relevent_experience', data=train)
# Out:
# C:\Users\Hp\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='relevent_experience', ylabel='count'>

# %%
sns.countplot(x='experience',hue='gender', data=train, palette='rainbow')
# Out:
# <AxesSubplot:xlabel='experience', ylabel='count'>

# %%
sns.countplot(x='gender',hue='experience', data=train, palette='rainbow')
# Out:
# <AxesSubplot:xlabel='gender', ylabel='count'>

# %%
sns.distplot(Aug['training_hours'].dropna(), kde=True, bins=30)
# Out:
# <AxesSubplot:xlabel='training_hours', ylabel='Density'>

# %%
Aug['company_size'].hist(bins=30, color='darkred', alpha=0.5)
# Out:
# <AxesSubplot:>

# %%
sns.countplot(x='experience', data=Aug, palette='dark')
# Out:
# <AxesSubplot:xlabel='experience', ylabel='count'>

# %%
train['city_development_index'].hist(color='pink',bins=20,figsize=(8,4))     ## HISTOGRAM PLOT
# Out:
# <AxesSubplot:>

# %%
# Data Cleaning

plt.figure(figsize=(12,7))
sns.boxplot(x='training_hours', y='company_size', data=train, palette='winter')
# Out:
# <AxesSubplot:xlabel='training_hours', ylabel='company_size'>

# %%
Aug.dtypes
# Out:
# enrollee_id                 int64
# city                       object
# city_development_index    float64
# gender                     object
# relevent_experience        object
# enrolled_university        object
# education_level            object
# major_discipline           object
# experience                 object
# company_size               object
# company_type               object
# last_new_job               object
# training_hours              int64
# target                    float64
# dtype: object

# %%
sns.heatmap(Aug.corr())
# Out:
# <AxesSubplot:>

# %% [markdown]
# # Jointplot
# ## DATASET Visadataset.csv

# %%
Visadataset= pd.read_csv('https://raw.githubusercontent.com/MesmerizingManisha9/testgitpush/master/Visadataset.csv')

# %%
Visadataset
# Out:
#          case_id continent education_of_employee has_job_experience  \
# 0         EZYV01      Asia           High School                  N
# 1         EZYV02      Asia              Master's                  Y
# 2         EZYV03      Asia            Bachelor's                  N
# 3         EZYV04      Asia            Bachelor's                  N
# 4         EZYV05    Africa              Master's                  Y
# ...          ...       ...                   ...                ...
# 25475  EZYV25476      Asia            Bachelor's                  Y
# 25476  EZYV25477      Asia           High School                  Y
# 25477  EZYV25478      Asia              Master's                  Y
# 25478  EZYV25479      Asia              Master's                  Y
# 25479  EZYV25480      Asia            Bachelor's                  Y
#
#       requires_job_training  no_of_employees  yr_of_estab  \
# 0                         N            14513         2007
# ...

# %%
sns.jointplot(x='yr_of_estab',y='prevailing_wage',data=Visadataset,kind='hex')

# %%
sns.jointplot(x='no_of_employees',y='prevailing_wage',data=Visadataset,kind='reg')

# %% [markdown]
# # pair Plot

# %%
sns.pairplot(Aug)

# %%
sns.pairplot(Visadataset, hue="education_of_employee")

# %% [markdown]
# # dataset blackFriday

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

import numpy as np

blackFriday= pd.read_csv('https://raw.githubusercontent.com/MesmerizingManisha9/testgitpush/master/blackFriday_train.csv')

# %%
blackFriday
# Out:
#         User_ID Product_ID Gender    Age  Occupation City_Category  \
# 0       1000001  P00069042      F   0-17          10             A
# 1       1000001  P00248942      F   0-17          10             A
# 2       1000001  P00087842      F   0-17          10             A
# 3       1000001  P00085442      F   0-17          10             A
# 4       1000002  P00285442      M    55+          16             C
# ...         ...        ...    ...    ...         ...           ...
# 550063  1006033  P00372445      M  51-55          13             B
# 550064  1006035  P00375436      F  26-35           1             C
# 550065  1006036  P00375436      F  26-35          15             B
# 550066  1006038  P00375436      F    55+           1             C
# 550067  1006039  P00371644      F  46-50           0             B
#
#        Stay_In_Current_City_Years  Marital_Status  Product_Category_1  \
# 0                               2               0                   3
# ...

# %%
labels=('Product_Category_3', 'Purchase', 'Product_Category_1', 'Product_Category_2',)
sizes= [385, 323, 250, 150]
colors=['gold','yellowgreen','lightcoral','lightskyblue']

explode=(0.15,0,0,0)

plt.pie(sizes, colors=colors, explode=explode, labels=labels,  autopct='%1.1f%%', shadow=True)

plt.axis('equal')
plt.show()

# %%
x=np.arange(0,10)
y=np.arange(11,21)

# %%
## plotting using matplotlib

## plt scatter

plt.scatter(Gender,Purchase,c='r')
plt.xlabel('x axis')
plt.ylabel('Purchase')
plt.title('Graph in 2D')
plt.savefig('Test.png')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_4212/1996635874.py in <module>
#       3 ## plt scatter
#       4
# ----> 5 plt.scatter(Gender,Purchase,c='r')
#       6 plt.xlabel('x axis')
#       7 plt.ylabel('Purchase')
#
# NameError: name 'Gender' is not defined

# %%
#creating a EDA report
import sweetviz as sv
analyze_report = sv.analyze(Aug)
analyze_report.show_html('analyze.html', open_browser=False)

import IPython
IPython.display.HTML('analyze.html')
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_4212/1476796533.py in <module>
#       1 #creating a EDA report
# ----> 2 import sweetviz as sv
#       3 analyze_report = sv.analyze(Aug)
#       4 analyze_report.show_html('analyze.html', open_browser=False)
#       5
#
# ModuleNotFoundError: No module named 'sweetviz'

# %%
df
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_4212/1396537375.py in <module>
# ----> 1 df
#
# NameError: name 'df' is not defined
